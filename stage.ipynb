# %%
import pandas as pd

# %%
data = pd.read_csv('./test_data.csv')
data['caldt'] = pd.to_datetime(data['caldt'])
# Out:
# /var/folders/dj/z601f8896m990_cv_nbdkv0m0000gn/T/ipykernel_86222/2760837564.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('./test_data.csv')

# %%
data
# Out:
#           crsp_fundno       caldt   dnav       dret
# 0                 105  2024-01-02  11.55  -0.013664
# 1                 105  2024-01-03  11.30  -0.021645
# 2                 105  2024-01-04  11.27  -0.002655
# 3                 105  2024-01-05  11.27        0.0
# 4                 105  2024-01-08  11.45   0.015972
# ...               ...         ...    ...        ...
# 15001759       104676  2025-12-24  65.58   0.002752
# 15001760       104676  2025-12-26  65.59   0.000152
# 15001761       104676  2025-12-29  65.30  -0.002775
# 15001762       104676  2025-12-30  65.29  -0.000153
# 15001763       104676  2025-12-31  64.88  -0.006280
#
# [15001764 rows x 4 columns]

# %%
data.query("crsp_fundno == 105").set_index('caldt')['dnav'].plot()
# Out:
# <Axes: xlabel='caldt'>

# %%
len(data['crsp_fundno'].unique())
# Out:
# 33197
